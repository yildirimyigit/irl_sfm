# %%
import numpy as np
import os

data_path = '/home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/'
out_path = '/home/yigit/phd/yigit_phd_thesis/cnmp/data/sfm/1_obs_moving/'

try:
    os.mkdir(f'{out_path}demonstrations')
except:
  pass
try:
    os.mkdir(f'{out_path}novel')
except:
  pass

demonstrations = []
novel_demonstrations = []

for filename in os.listdir(data_path):
    if filename.endswith(".npy"):
        path = os.path.join(data_path, filename)
        if '-10' not in filename:
            demonstrations.append(np.load(path, allow_pickle=True, encoding='latin1'))
            print(f'{len(demonstrations)-1}: {path}')

novel_data_path = os.path.join(data_path, 'novel/')
for filename in os.listdir(novel_data_path):
    if filename.endswith(".npy"):
        path = os.path.join(novel_data_path, filename)
        novel_demonstrations.append(np.load(path, allow_pickle=True, encoding='latin1'))

num_demos = len(demonstrations)
num_novel = 1
# Out:
# 0: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/5.5.npy
# 1: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/8.5.npy
# 2: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/5.0.npy
# 3: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/3.5.npy
# 4: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/1.0.npy
# 5: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/6.0.npy
# 6: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-7.5.npy
# 7: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-1.0.npy
# 8: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/4.0.npy
# 9: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-2.5.npy
# 10: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-2.0.npy
# 11: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-6.5.npy
# 12: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/2.0.npy
# 13: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/3.0.npy
# 14: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/4.5.npy
# 15: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-3.5.npy
# 16: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-9.0.npy
# 17: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-5.5.npy
# 18: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/8.0.npy
# 19: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/9.0.npy
# 20: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-6.0.npy
# 21: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-1.5.npy
# 22: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/10.0.npy
# 23: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/1.5.npy
# 24: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-8.0.npy
# 25: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-4.5.npy
# 26: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-4.0.npy
# 27: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-7.0.npy
# 28: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/7.5.npy
# 29: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-8.5.npy
# 30: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-3.0.npy
# 31: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-9.5.npy
# 32: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/9.5.npy
# 33: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/6.5.npy
# 34: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/-5.0.npy
# 35: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/2.5.npy
# 36: /home/yigit/Documents/projects/irl_sfm/data/demonstrations/sfm/1_obs_moving/7.0.npy

# %%
desired_len = 400 # min_len
x_dim, gamma_dim, y_dim = 2, 2, 2

d_X = np.zeros((num_demos, desired_len, x_dim))
d_Gamma =  np.zeros((num_demos, desired_len, gamma_dim))
d_Y = np.zeros((num_demos, desired_len, y_dim))
n_X = np.zeros((num_novel, desired_len, x_dim))
n_Gamma =  np.zeros((num_novel, desired_len, gamma_dim))
n_Y = np.zeros((num_novel, desired_len, y_dim))

for i, demo in enumerate(demonstrations):
    len_demo = len(demo)
    indices = np.linspace(0, len_demo-1, desired_len, dtype=int)  # <desired_len>-many indices are selected uniformly
    x, gmm, y = np.zeros((desired_len, x_dim)), np.zeros((desired_len, gamma_dim)), np.zeros((desired_len, y_dim))
    for new_ind, old_ind in enumerate(indices):
        x[new_ind] = demo[old_ind][:x_dim]
        gmm[new_ind] = demo[old_ind][x_dim:x_dim+gamma_dim]
        y[new_ind] = demo[old_ind][-y_dim:]
    d_X[i] = x
    d_Gamma[i] = gmm
    d_Y[i] = y

#############    
# novel case
#############

for i, demo in enumerate(novel_demonstrations):
    len_demo = len(demo)
    indices = np.linspace(0, len_demo-1, desired_len, dtype=int)  # <desired_len>-many indices are selected uniformly
    x, gmm, y = np.zeros((desired_len, x_dim)), np.zeros((desired_len, gamma_dim)), np.zeros((desired_len, y_dim))
    for new_ind, old_ind in enumerate(indices):
        x[new_ind] = demo[old_ind][:x_dim]
        gmm[new_ind] = demo[old_ind][x_dim:x_dim+gamma_dim]
        y[new_ind] = demo[old_ind][-y_dim:]
    n_X[i] = x
    n_Gamma[i] = gmm
    n_Y[i] = y

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [16, 10]

fig, axs = plt.subplots(2, 2)
for i in range(num_demos):
    axs[0, 0].plot(range(len(d_Y[i])), d_Y[i][:, 0])  # v_x
axs[0, 0].set_title('v_x values')
axs[0, 0].set(xlabel='step', ylabel='speed')

for i in range(num_demos):
    axs[0, 1].plot(range(len(d_Y[i])), d_Y[i][:, 1])  # v_y
axs[0, 1].set_title('v_y values')
axs[0, 1].set(xlabel='step', ylabel='speed')

axs[1, 0].plot(range(len(n_Y[0])), n_Y[0][:, 0])  # v_x
axs[1, 0].set_title('novel v_x values')
axs[1, 0].set(xlabel='step', ylabel='speed')

axs[1, 1].plot(range(len(n_Y[0])), n_Y[0][:, 1])  # v_y
axs[1, 1].set_title('novel v_y values')
axs[1, 1].set(xlabel='step', ylabel='speed')
# Out:
# [Text(0, 0.5, 'speed'), Text(0.5, 0, 'step')]

# %%
num_val = 5

x_train, x_val, y_train, y_val, gamma_train, gamma_val = [], [], [], [], [], []
val_indices = np.sort(np.random.choice(range(num_demos-1), num_val, replace=False))

for i in range(num_demos):
    if i in val_indices:  # validation instance
        print(f'val: {i}')
        x_val.append(d_X[i])
        gamma_val.append(d_Gamma[i])
        y_val.append(d_Y[i])
    else:  # training instance
        print(f'train: {i}')
        x_train.append(d_X[i])
        gamma_train.append(d_Gamma[i])
        y_train.append(d_Y[i])
        
np.save(out_path + 'demonstrations/' + 'd_x.npy', np.array(x_train))
np.save(out_path + 'demonstrations/' + 'd_y.npy', np.array(y_train))
np.save(out_path + 'demonstrations/' + 'd_gamma.npy', np.array(gamma_train))
np.save(out_path + 'demonstrations/' + 'v_d_x.npy', np.array(x_val))
np.save(out_path + 'demonstrations/' + 'v_d_y.npy', np.array(y_val))
np.save(out_path + 'demonstrations/' + 'v_d_gamma.npy', np.array(gamma_val))

#############
# novel case
#############

np.save(out_path + 'novel/' + 'd_x.npy', np.array(n_X))
np.save(out_path + 'novel/' + 'd_y.npy', np.array(n_Y))
np.save(out_path + 'novel/' + 'd_gamma.npy', np.array(n_Gamma))
# Out:
# train: 0
# val: 1
# train: 2
# train: 3
# train: 4
# train: 5
# train: 6
# train: 7
# train: 8
# train: 9
# train: 10
# train: 11
# train: 12
# val: 13
# train: 14
# train: 15
# train: 16
# train: 17
# val: 18
# train: 19
# train: 20
# train: 21
# train: 22
# train: 23
# val: 24
# train: 25
# train: 26
# train: 27
# train: 28
# train: 29
# train: 30
# train: 31
# train: 32
# train: 33
# train: 34
# val: 35
# train: 36
