# %%
import numpy as np

data_path = '/home/yigit/phd/yigit_phd_thesis/cnmp/output/1591828422/poses.npy'
poses = np.load(data_path, allow_pickle=True, encoding='latin1')[:700]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [50, 10]

plt.plot(poses[:, 0], poses[:, 1]-2.5, color='black')
plt.xlabel('x position')
plt.ylabel('y position')
# Out:
# Text(0, 0.5, 'y position')
